# %%
# !python train.py --gcn_bool --adjtype doubletransition --addaptadj  --randomadj --device cuda:0
# Out:
#  MAPE: 0.0624, Train RMSE: 4.8647
# Iter: 250, Train Loss: 2.4613, Train MAPE: 0.0660, Train RMSE: 4.7396
# Iter: 300, Train Loss: 2.3324, Train MAPE: 0.0565, Train RMSE: 4.2906
# Iter: 350, Train Loss: 2.2542, Train MAPE: 0.0545, Train RMSE: 4.2379
# Epoch: 074, Inference Time: 12.3224 secs
# Epoch: 074, Train Loss: 2.4038, Train MAPE: 0.0610, Train RMSE: 4.4573, Valid Loss: 3.0249, Valid MAPE: 0.0859, Valid RMSE: 5.6518, Training Time: 301.3460/epoch
# Iter: 000, Train Loss: 2.4128, Train MAPE: 0.0606, Train RMSE: 4.5323
# Iter: 050, Train Loss: 2.2675, Train MAPE: 0.0549, Train RMSE: 4.3465
# Iter: 100, Train Loss: 2.2924, Train MAPE: 0.0586, Train RMSE: 4.2962
# Iter: 150, Train Loss: 2.5314, Train MAPE: 0.0656, Train RMSE: 4.6140
# Iter: 200, Train Loss: 2.3677, Train MAPE: 0.0589, Train RMSE: 4.3471
# Iter: 250, Train Loss: 2.4737, Train MAPE: 0.0632, Train RMSE: 4.6300
# Iter: 300, Train Loss: 2.4073, Train MAPE: 0.0608, Train RMSE: 4.4502
# ...

# %%
# !python train.py --gcn_bool --adjtype doubletransition --addaptadj  --randomadj --device cuda:0  --epochs 5
# Out:
# Namespace(addaptadj=True, adjdata='data/sensor_graph/adj_mx.pkl', adjtype='doubletransition', aptonly=False, batch_size=64, data='data/METR-LA', device='cuda:0', dropout=0.3, epochs=5, expid=1, gcn_bool=True, in_dim=2, learning_rate=0.001, nhid=32, num_nodes=207, print_every=50, randomadj=True, save='./garage/metr', seq_length=12, weight_decay=0.0001)
# start training...
# Iter: 000, Train Loss: 2.3041, Train MAPE: 0.0576, Train RMSE: 4.2257
# Iter: 050, Train Loss: 2.3290, Train MAPE: 0.0590, Train RMSE: 4.2589
# Iter: 100, Train Loss: 2.4105, Train MAPE: 0.0611, Train RMSE: 4.3299
# Iter: 150, Train Loss: 2.3442, Train MAPE: 0.0556, Train RMSE: 4.3048
# Iter: 200, Train Loss: 2.2789, Train MAPE: 0.0535, Train RMSE: 4.1901
# Iter: 250, Train Loss: 2.2851, Train MAPE: 0.0573, Train RMSE: 4.1322
# Iter: 300, Train Loss: 2.4026, Train MAPE: 0.0596, Train RMSE: 4.2669
# Iter: 350, Train Loss: 2.2962, Train MAPE: 0.0573, Train RMSE: 4.3619
# Epoch: 001, Inference Time: 12.0986 secs
# ...

# %%
# !python train.py --gcn_bool --adjtype doubletransition --addaptadj  --randomadj --device cuda:0
# Out:
# Namespace(addaptadj=True, adjdata='data/sensor_graph/adj_mx.pkl', adjtype='doubletransition', aptonly=False, batch_size=64, data='data/METR-LA', device='cuda:0', dropout=0.3, epochs=100, expid=1, gcn_bool=True, in_dim=2, learning_rate=0.001, nhid=32, num_nodes=207, print_every=50, randomadj=True, save='./garage/metr', seq_length=12, weight_decay=0.0001)
# Training finished
# Evaluate best model on test data for horizon 1, Test MAE: 2.4627, Test MAPE: 0.0613, Test RMSE: 4.1247
# Evaluate best model on test data for horizon 2, Test MAE: 2.8384, Test MAPE: 0.0738, Test RMSE: 5.0421
# Evaluate best model on test data for horizon 3, Test MAE: 3.1248, Test MAPE: 0.0838, Test RMSE: 5.7341
# Evaluate best model on test data for horizon 4, Test MAE: 3.3611, Test MAPE: 0.0919, Test RMSE: 6.2785
# Evaluate best model on test data for horizon 5, Test MAE: 3.5557, Test MAPE: 0.0987, Test RMSE: 6.7163
# ...
